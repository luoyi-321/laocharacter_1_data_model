# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
imgs = np.load('/content/drive/MyDrive/data_1/images.npy')
imgs.shape
# Out:
# (270, 50, 50)

# %%
img = imgs[60:70]

# %%
img.shape
# Out:
# (10, 50, 50)

# %%
img = np.expand_dims(img, -1)

# %%
img = np.array(img).astype(float).reshape(1,50,50,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-82b1bff2ab78> in <cell line: 1>()
# ----> 1 img = np.array(img).astype(float).reshape(1,50,50,1)
#
# ValueError: cannot reshape array of size 25000 into shape (1,50,50,1)

# %%
img.shape
# Out:
# (10, 50, 50, 1)

# %%
img.shape
# Out:
# (50, 50, 1, 1)

# %%
for i in range(len(img)):
  plt.figure()
  plt.imshow(img[i])
  plt.grid(False)
plt.show()

# %%
model = keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/model_/laocharacter_predict_model_v1.model")

# %%
predict_lette = np.argmax(model.predict(img),axis = -1)
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
print(predict_lette)
# Out:
# [ 7  8  9 10 11 12 20 14 15 16]

# %%
# !pip install bidict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bidict import bidict

# %%
ENCODER = bidict({
    'ກ':1,'ຂ':2,'ຄ':3,'ງ':4,'ຈ':5,'ສ':6,'ຊ':7,'ຍ':8,'ດ':9,'ຕ':10,'ຖ':11,'ທ':12,
    'ນ':13,'ບ':14,'ປ':15,'ຜ':16,'ຝ':17,'ພ':18,'ຟ':19,'ມ':20,'ຢ':21,'ຣ':22,'ລ':23,'ວ':24,
    'ຫ':25,'ອ':26,'ຮ':27
})

# %%
letter =[]
for  i in range(len(predict_lette)):
  ltt = ENCODER.inverse[predict_lette[i]]
  letter = np.append(letter,ltt)

print(letter)
# Out:
# ['ຊ' 'ຍ' 'ດ' 'ຕ' 'ຖ' 'ທ' 'ມ' 'ບ' 'ປ' 'ຜ']
